# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', None)

itemdf = pd.read_excel("StockDB.xlsx", sheet_name='Item')
#categorydf = pd.read_excel("StockDB.xlsx", sheet_name='Category')
transMasterdf = pd.read_excel("StockDB.xlsx", sheet_name='STK_TransMaster')
transDetailsdf= pd.read_excel("StockDB.xlsx", sheet_name='STK_TransDetails')

# %%
transDetailsdf.head()
# Out:
#   TransType  TransDate  Year  TransNO  InvRefNo StoreFr StoreTo  PSID  \
# 0       BUY 2018-08-31  2018        1       NaN     NaN     S01   NaN
# 1       BUY 2018-08-31  2018        1       NaN     NaN     S01   NaN
# 2       BUY 2018-08-31  2018        1       NaN     NaN     S01   NaN
# 3       BUY 2018-08-31  2018        1       NaN     NaN     S01   NaN
# 4       BUY 2018-08-31  2018        1       NaN     NaN     S01   NaN
#
#            LCID  LCDate        Remarks  TransSl    ItemID    Unit   Qty  \
# 0  102050100001     1.0  OPENING STOCK        1  10010001  CARTON  2013
# 1  102050100001     1.0  OPENING STOCK       10  10010012  CARTON    64
# 2  102050100001     1.0  OPENING STOCK       11  10010014  CARTON    20
# 3  102050100001     1.0  OPENING STOCK       12  10010015  CARTON    16
# 4  102050100001     1.0  OPENING STOCK       13  10010032  CARTON    35
#
#      Rate     Amount    UserPc  UserId              InTime             IP  \
# 0  1700.0  3422100.0  mi3-wtr1   10101 2018-09-16 16:41:00   70.32.29.156
# 1  1940.0   124160.0  mi3-wtr1   10101 2018-10-31 19:43:00   70.32.29.156
# 2  1732.0    34640.0  mi3-wtr1   10101 2019-01-17 14:36:00  162.249.5.171
# 3  1936.0    30976.0  mi3-wtr1   10101 2019-01-17 17:24:00  162.249.5.171
# 4  2350.0    82250.0  mi3-wtr1   10101 2019-09-05 15:24:00  162.249.5.171
#
#           UpdatePC  UpdateUserID          UpdateTime       UpdateIP
# 0  WIN-COP36UURNHE       10101.0 2020-05-20 02:40:00  103.3.164.161
# 1         mi3-wtr1       10101.0 2019-10-01 17:10:00  162.249.5.171
# 2              NaN           NaN                 NaT            NaN
# 3              NaN           NaN                 NaT            NaN
# 4              NaN           NaN                 NaT            NaN

# %%
def fetch_brand(ItemID):
    row = itemdf[itemdf.ItemId == ItemID]
    ItemName = row.ItemName.to_string(index=False)
    Brand = row.Brand.to_string(index=False)
    return ItemName, Brand

# %%
sale_qty = {}
sale_money_amount = {}

for type, type_df in transDetailsdf.groupby('TransType'):
    if(type=='SALE'):
        for ItemID, ItemID_df in type_df.groupby('ItemID'):
            sale_qty[ItemID] = ItemID_df['Qty'].sum()
            sale_money_amount[ItemID] = ItemID_df['Amount'].sum()

print('ItemID \t\tItemName \tBrand \t\tQunatity')
for ItemID in sale_qty:
    ItemName,Brand = fetch_brand(ItemID)
    print(ItemID, ItemName, Brand, '\t', sale_qty[ItemID])
# Out:
# ItemID 		ItemName 	Brand 		Qunatity
# 10010001 1PLY RASCHEL BLANKET SULTAN 	 15252
# 10010002 1PLY RASCHEL BLANKET RIO 	 14930
# 10010003 1PLY RASCHEL BLANKET VICTORIYA 	 14095
# 10010004 1PLY RASCHEL BLANKET JASMINE 	 30428
# 10010005 1PLY RASCHEL BLANKET MASHREQ  	 12134
# 10010053 1PLY RASCHEL BLANKET BURJ 	 7044
# 10020001 2PLY RASCHEL BLANKET BURJ 	 3990
# 10020002 2PLY RASCHEL BLANKET GOLDEN FUN 	 10717
# 10020003 2PLY RASCHEL BLANKET BREEZE 	 20069
# 10020004 2PLY WEFT BLANKET SULTAN 	 15598
# 10020005 2PLY WEFT BLANKET JASMINE 	 3913
# 10020006 2PLY CLOUDY BLANKET SUNSET 	 5313
# 10020007 2PLY WEFT BLANKET JULIET 	 3410
# 10020008 2PLY RASCHEL BLANKET AROMA GOLD 	 20
# 10020009 2PLY RASCHEL BLANKET ESKIMO GOLD 	 3052
# 10020010 2PLY WEFT BLANKET MOOR GOLD 	 26924
# 10020011 2PLY WEFT BLANKET ABIDAL 	 360
# 10020012 2PLY RASCHEL BLANKET ESKIMO GOLD 	 5519
# 10020013 2PLY WEFT BLANKET DOLPHIN 	 100
# 10020014 2PLY WEFT BLANKET SOLARON SO 	 80
# 10020015 2PLY CLOUDY BLANKET CLOUDY PRINCE 	 7257
# 10020016 2PLY RASCHEL BLANKET ZENEX 	 45
# 10020017 2PLY WEFT BLANKET NATURELIFE 	 10498
# 10020018 2PLY WEFT BLANKET ARSHIYA QUEEN 	 3720
# 10020019 2PLY RASCHEL BLANKET GOLDEN HORSE 	 3154
# 10020020 2PLY WEFT BLANKET ROMANTIC 	 12
# 10020021 2PLY RASCHEL BLANKET GOOD LIFE 	 3241
# 10020022 2PLY CLOUDY BLANKET SOLARON SOFT 	 8093
# 10020023 2PLY WEFT BLANKET  MUGHAL 	 12740
# 10020024 2PLY RASCHEL BLANKET SUPER KING 	 21
# 10020025 2PLY WEFT BLANKET GOLDEN FLOWER 	 14229
# 10020026 2PLY RASCHEL BLANKET SOLARON QUEEN 	 6
# 10020027 2PLY RASCHEL BABY BABY KING 	 1464
# 10020028 2PLY CLOUDY BLANKET AROMA 	 3092
# 10020029 2PLY WEFT BLANKET DIAMOND KING 	 30
# 10020030 2PLY WEFT BLANKET DOLPHIN GOLD 	 7
# 10020031 2PLY WEFT BLANKET DOLPHIN 	 22
# 10020032 2PLY WEFT BLANKET JASMINE (6)  	 2653
# 10020033 2PLY RASCHEL BLANKET RASCHEL GOLD 	 6273
# 10020034 2PLY CLOUDY SOLARON BABY 	 232
# 10020035 2PLY WEFT BLANKET  ZARA 	 4220
# 10020036 2PLY WEFT BLANKET PANDA 	 23008
# 10020037 2PLY CLOUDY BABY MICKEY & MOUSE BABY 	 16316
# 10020038 2PLY CLOUDY BABY DISNEY BABY 	 5968
# 10020039 2PLY WEFTBLANKET JASMINE (2) 	 768

# %%
print('ItemID \t\tItemName \tBrand \t\tmoneyAmount')
for ItemID in sale_money_amount:
    ItemName,Brand = fetch_brand(ItemID)
    print(ItemID, ItemName, Brand, '\t', sale_money_amount[ItemID])
# Out:
# ItemID 		ItemName 	Brand 		moneyAmount
# 10010001 1PLY RASCHEL BLANKET SULTAN 	 27883400.0
# 10010002 1PLY RASCHEL BLANKET RIO 	 27400960.0
# 10010003 1PLY RASCHEL BLANKET VICTORIYA 	 21406600.0
# 10020038 2PLY CLOUDY BABY DISNEY BABY 	 4948960.0
# 10020039 2PLY WEFTBLANKET JASMINE (2) 	 1729280.0

# %% [markdown]
# <h2> answer to question 1 & 2: <h2>

# %%
lowest_sale_qty_item = min(sale_qty, key=sale_qty.get) #gets key of min value of dictionary
highest_sale_qty_item = max(sale_qty, key=sale_qty.get)
min_qty_value = min(sale_qty.values())
max_qty_value = max(sale_qty.values())

ItemName, Brand = fetch_brand(lowest_sale_qty_item)

print('Based on quantity কোন ধরনের প্রোডাক্ট কম সেল হইসেঃ')
print('ItemID \t\tItemName \tBrand \tquantity')
print(lowest_sale_qty_item, ItemName, Brand, min_qty_value)

ItemName, Brand = fetch_brand(highest_sale_qty_item)

print('\nBased on quantity কোন ধরনের প্রোডাক্ট বেশি সেল হইসেঃ')
print('ItemID \t\tItemName \tBrand \t\tquantity')
print(highest_sale_qty_item, ItemName, Brand, max_qty_value)
# Out:
# Based on quantity কোন ধরনের প্রোডাক্ট কম সেল হইসেঃ
# ItemID 		ItemName 	Brand 	quantity
# 10020026 2PLY RASCHEL BLANKET SOLARON QUEEN 6
#
# Based on quantity কোন ধরনের প্রোডাক্ট বেশি সেল হইসেঃ
# ItemID 		ItemName 	Brand 		quantity
# 10010050 1PLY CLOUDY BABY KINGSTAR CLOUDY BABY 39158

# %%
lowest_sale_money_amount = min(sale_money_amount, key=sale_money_amount.get) #gets key of min value of dictionary
highest_sale_moeny_amount = max(sale_money_amount, key=sale_money_amount.get)
min_money_value = min(sale_money_amount.values())
max_moeny_value = max(sale_money_amount.values())

ItemName, Brand = fetch_brand(lowest_sale_money_amount)

print('Based on moneyAmount কোন ধরনের প্রোডাক্ট কম সেল হইসেঃ')
print('ItemID \t\tItemName \tBrand \tmoneyAmount')
print(lowest_sale_money_amount, ItemName, Brand, min_money_value)

ItemName, Brand = fetch_brand(highest_sale_moeny_amount)

print('\nBased on moneyAmount কোন ধরনের প্রোডাক্ট বেশি সেল হইসেঃ')
print('ItemID \t\tItemName \tBrand \tmoneyAmount')
print(highest_sale_moeny_amount, ItemName, Brand, max_moeny_value)
# Out:
# Based on moneyAmount কোন ধরনের প্রোডাক্ট কম সেল হইসেঃ
# ItemID 		ItemName 	Brand 	moneyAmount
# 10020030 2PLY WEFT BLANKET DOLPHIN GOLD 17395.0
#
# Based on moneyAmount কোন ধরনের প্রোডাক্ট বেশি সেল হইসেঃ
# ItemID 		ItemName 	Brand 	moneyAmount
# 10020003 2PLY RASCHEL BLANKET BREEZE 60906770.0

# %% [markdown]
# <h2>3. per year:
# remaining stock = buy qty - sale qty <h2>

# %%
buy = {}
sale = {}

for type, type_df in transDetailsdf.groupby('TransType'):
    if(type=='BUY'):
        for year, year_df in type_df.groupby('Year'):
            buy[year] = year_df['Qty'].sum()
            print(type,year, year_df['Qty'].sum())

#print('\n')
for type, type_df in transDetailsdf.groupby('TransType'):
    if(type=='SALE'):
        for year, year_df in type_df.groupby('Year'):
            sale[year] = year_df['Qty'].sum()
            print(type,year, year_df['Qty'].sum())

#print('\n')
print('buy:')
print(buy) #each yr total koto quantity buy hoise
print('sale:')
print(sale)

stock = {} #each yr e stock e remaining
for year in buy:
    stock[year] = buy[year] - sale[year]
    # if(year!= 2018):
    #     stock[year] = stock[year] + stock[year-1]
print('stock remaining:')
print(stock)
# Out:
# BUY 2018 209964
# BUY 2019 175300
# BUY 2020 174985
# BUY 2021 184681
# SALE 2018 187229
# SALE 2019 169576
# SALE 2020 191803
# SALE 2021 182205
# buy:
# {2018: 209964, 2019: 175300, 2020: 174985, 2021: 184681}
# sale:
# {2018: 187229, 2019: 169576, 2020: 191803, 2021: 182205}
# stock remaining:
# {2018: 22735, 2019: 5724, 2020: -16818, 2021: 2476}

# %% [markdown]
# <h2>stock predict for next year 2021:<h2>

# %%
data = []
for year in stock:
    if(year!=2021):
        data.append([year, stock[year]])

df = pd.DataFrame(data, columns = ['year', 'stock'])

x = df.drop(['stock'],axis='columns')
y = df.stock

from sklearn.linear_model import LinearRegression
lr_clf = LinearRegression()
lr_clf.fit(x,y)

#predict for year 2021:
print("predict stock for year 2021: ")
print(lr_clf.predict([[2021]]))
#ans is stock = -35672
print('actual stock of year 2021: ',stock[2021])
# Out:
# predict stock for year 2021:
# [-35672.66666666]
# actual stock of year 2021:  2476

# %% [markdown]
# <h2>4. money amount invest in buying for next year 2021: <h2>

# %%
amount_invest= {}
for type, type_df in transDetailsdf.groupby('TransType'):
    if(type=='BUY'):
        for year, year_df in type_df.groupby('Year'):
            print(type,year, year_df['Amount'].sum())
            amount_invest[year] =year_df['Amount'].sum()
# Out:
# BUY 2018 328025647.08000004
# BUY 2019 260479568.48999998
# BUY 2020 297123011.49
# BUY 2021 326807896.15

# %%
data = []
for year in amount_invest:
    if(year!=2021):
        data.append([year, amount_invest[year]])

df2 = pd.DataFrame(data, columns = ['year', 'investAmount'])

x = df2.drop(['investAmount'],axis='columns')
y = df2.investAmount

from sklearn.linear_model import LinearRegression
lr_clf = LinearRegression()
lr_clf.fit(x,y)
#predict investAmount for year 2022:
print('predict investAmount for year 2021:')
ans = lr_clf.predict([[2021]])
print("%.2f" % ans)
#ans is = 264306773
print('actual investAmount on year 2021: ',amount_invest[2021])
# Out:
# predict investAmount for year 2021:
# 264306773.43
# actual investAmount on year 2021:  326807896.15

# %%
#creating test data set
data = [
    [2021, 326807896.15],
    [2021, 326807896.15]
]

testdf = pd.DataFrame(data, columns = ['year', 'investAmount'])

x_test = testdf.drop(['investAmount'],axis='columns')
y_test = testdf.investAmount


lr_clf.score(x_test, y_test)
# Out:
# 0.0

# %%
from sklearn.tree import DecisionTreeRegressor
# Fit regression model
regr = DecisionTreeRegressor(max_depth=2)
regr.fit(x, y)
print('predict investAmount for year 2021:')
ans = regr.predict([[2021]])
print("%.2f" % ans)

print('actual investAmount on year 2021: ',amount_invest[2021])
print('score: ', regr.score(x_test, y_test))
# Out:
# predict investAmount for year 2021:
# 297123011.49
# actual investAmount on year 2021:  326807896.15
# score:  0.0

# %%
from sklearn.svm import SVR
# Fit regression model
svr = SVR().fit(x, y)
print('predict investAmount for year 2021:')
ans = svr.predict([[2021]])
print("%.2f" % ans)

print('actual investAmount on year 2021: ',amount_invest[2021])
print('score: ', svr.score(x_test, y_test))
# Out:
# predict investAmount for year 2021:
# 297123011.71
# actual investAmount on year 2021:  326807896.15
# score:  0.0

# %%
from sklearn import linear_model
# Fit regression model
lassoReg = linear_model.Lasso(alpha=0.1)
lassoReg.fit(x,y)
# Predict
print('predict investAmount for year 2021:')
ans = lassoReg.predict([[2021]])
print("%.2f" % ans)

print('actual investAmount on year 2021: ',amount_invest[2021])
print('score: ', lassoReg.score(x_test, y_test))
# Out:
# predict investAmount for year 2021:
# 264306773.73
# actual investAmount on year 2021:  326807896.15
# score:  0.0

# %%
from sklearn.ensemble import RandomForestRegressor
rfr = RandomForestRegressor(max_depth=3)
rfr.fit(x, y)
print('predict investAmount for year 2021:')
ans = rfr.predict([[2021]])
print("%.2f" % ans)

print('actual investAmount on year 2021: ',amount_invest[2021])
print('score: ', rfr.score(x_test, y_test))
# Out:
# predict investAmount for year 2021:
# 287789926.52
# actual investAmount on year 2021:  326807896.15
# score:  0.0

# %% [markdown]
# <h2>5. Profit each year: salePrice - buyPrice<h2>

# %%
buyPrice = {} 
salePrice = {}

for type, type_df in transDetailsdf.groupby('TransType'):
    if(type=='BUY'):
        for year, year_df in type_df.groupby('Year'):
            buyPrice[year] = year_df['Amount'].sum()
            print(type,year, year_df['Amount'].sum())

#print('\n')
for type, type_df in transDetailsdf.groupby('TransType'):
    if(type=='SALE'):
        for year, year_df in type_df.groupby('Year'):
            salePrice[year] = year_df['Amount'].sum()
            print(type,year, year_df['Amount'].sum())

#print('\n')
print('buy:')
print(buyPrice)
print('sale:')
print(salePrice)

profit = {} #each yr e profit
for year in buy:
    profit[year] = salePrice[year] - buyPrice[year]

print('profit:')
print(profit)
# Out:
# BUY 2018 328025647.08000004
# BUY 2019 260479568.48999998
# BUY 2020 297123011.49
# BUY 2021 326807896.15
# SALE 2018 336986810.0
# SALE 2019 309949565.0
# SALE 2020 372781099.0
# SALE 2021 376318562.0
# buy:
# {2018: 328025647.08000004, 2019: 260479568.48999998, 2020: 297123011.49, 2021: 326807896.15}
# sale:
# {2018: 336986810.0, 2019: 309949565.0, 2020: 372781099.0, 2021: 376318562.0}
# profit:
# {2018: 8961162.919999957, 2019: 49469996.51000002, 2020: 75658087.50999999, 2021: 49510665.850000024}

# %%
data = []
for year in profit:
    if(year!=2021):
        data.append([year, profit[year]])

df3 = pd.DataFrame(data, columns = ['year', 'profit'])

x = df3.drop(['profit'],axis='columns')
y = df3.profit

from sklearn.linear_model import LinearRegression
lr_clf = LinearRegression()
lr_clf.fit(x,y)

print('predict profit for year 2021:')
ans = lr_clf.predict([[2021]])
print("%.2f" % ans)
print('actual profit on year 2021: ',amount_invest[2021])
# Out:
# predict profit for year 2021:
# 111393340.24
# actual profit on year 2021:  326807896.15

# %% [markdown]
# <h2>6. which brand highest profit: <h2>

# %%
profitBrand = {}

for ItemID, ItemID_df in transDetailsdf.groupby('ItemID'):
    buydf = ItemID_df[ItemID_df.TransType=='BUY']
    buy_sum = buydf.Amount.sum()
    saledf = ItemID_df[ItemID_df.TransType=='SALE']
    sale_sum = saledf.Amount.sum()
    profit = sale_sum - buy_sum

    ItemName, Brand = fetch_brand(ItemID)

    profitBrand[Brand] = profit
    print('ItemID:',ItemID, 'profit:',profit, Brand, ItemName )
# Out:
# ItemID: 0 profit: 0.0 Series([], ) Series([], )
# ItemID: 10010001 profit: 2609590.8100000024 SULTAN 1PLY RASCHEL BLANKET
# ItemID: 10020018 profit: 2487592.3899999997 ARSHIYA QUEEN 2PLY WEFT BLANKET
# ItemID: 10020019 profit: 1602159.7699999996 GOLDEN HORSE 2PLY RASCHEL BLANKET
# ItemID: 10020020 profit: -600.0 ROMANTIC 2PLY WEFT BLANKET
# ItemID: 10020021 profit: 2504327.4000000004 GOOD LIFE 2PLY RASCHEL BLANKET
# ItemID: 10020022 profit: 3287341.5 SOLARON SOFT 2PLY CLOUDY BLANKET
# ItemID: 10020023 profit: 2501143.0700000003 MUGHAL 2PLY WEFT BLANKET
# ItemID: 10020024 profit: 420.0 SUPER KING 2PLY RASCHEL BLANKET
# ItemID: 10020025 profit: 4082576.8500000015 GOLDEN FLOWER 2PLY WEFT BLANKET
# ItemID: 10020026 profit: 300.0 SOLARON QUEEN 2PLY RASCHEL BLANKET
# ItemID: 10020027 profit: 1354160.0 BABY KING 2PLY RASCHEL BABY
# ItemID: 10020028 profit: 1646500.0 AROMA 2PLY CLOUDY BLANKET
# ItemID: 10020029 profit: -3000.0 DIAMOND KING 2PLY WEFT BLANKET
# ItemID: 10020030 profit: 385.0 DOLPHIN GOLD 2PLY WEFT BLANKET
# ItemID: 10020031 profit: 880.0 DOLPHIN 2PLY WEFT BLANKET
# ItemID: 10020032 profit: -546100.9800000004 JASMINE (6)  2PLY WEFT BLANKET
# ItemID: 10020033 profit: 2308608.460000001 RASCHEL GOLD 2PLY RASCHEL BLANKET
# ItemID: 10020034 profit: -5600.0 SOLARON BABY 2PLY CLOUDY
# ItemID: 10020035 profit: 881020.0 ZARA 2PLY WEFT BLANKET
# ItemID: 10020036 profit: 1533131.1700000018 PANDA 2PLY WEFT BLANKET
# ItemID: 10020037 profit: 2574580.0 MICKEY & MOUSE BABY 2PLY CLOUDY BABY
# ItemID: 10020038 profit: 1368160.0 DISNEY BABY 2PLY CLOUDY BABY
# ItemID: 10020039 profit: -5792920.0 JASMINE (2) 2PLY WEFTBLANKET

# %%
print('brand profit highest to lowest: ')
dict(sorted(profitBrand.items(), reverse=True, key=lambda item: item[1]))
# Out:
# brand profit highest to lowest:
# {'MOOR GOLD': 7941332.280000001,
#  'SOLARON CLASSIC': 7932241.310000002,
#  'BREEZE': 7614813.969999999,
#  'EMIRATES': 5779292.770000003,
#  'QUEEN STAR': 5512946.960000001,
#  'CLOUDY PRINCE': 5106799.25,
#  'GOLDEN FUN': 4987229.380000003,
#  'OASIS': 4612937.970000001,
#  'ARABIAN KING': 4332984.34,
#  'TAMILON GOLD': 4083000.9400000013,
#  'GOLDEN FLOWER': 4082576.8500000015,
#  'RIO': 3915841.6000000015,
#  'BLACK EAGLE': 3697428.219999999,
#  'SOLARON SOFT': 3287341.5,
#  'PRESIDENT': 3287252.0600000005,
#  'MASHREQ ': 3243622.200000003,
#  'TAMILON KING': 3225782.009999998,
#  'ROSELAND': 3074530.8000000007,
#  'KING PRADO': 3055606.9800000004,
#  'VICTORIYA': 3050001.490000002,
#  'RAYMOND': 3038320.66,
#  'TAMILON': 2947971.450000001,
#  'KING POWER GOLD': 2865875.7300000004,
#  'MICKEY & MOUSE BABY': 2574580.0,
#  'GOOD LIFE': 2504327.4000000004,
#  'MUGHAL': 2501143.0700000003,
#  'ARSHIYA QUEEN': 2487592.3899999997,
#  'RASCHEL GOLD': 2308608.460000001,
#  'SULTAN': 2188522.1799999997,
#  'NATURELIFE': 2137799.759999998,
#  'GOLDEN BABY': 2107618.329999998,
#  'OLYMPIA GOLD': 2106703.740000002,
#  'RICHSHINE': 2062030.9000000004,
#  'TRUELOVE': 1923083.6899999995,
#  'ESKIMO GOLD': 1763516.6499999985,
#  'AROMA': 1646500.0,
#  'GOLDEN HORSE': 1602159.7699999996,
#  'TENDER TOUCH': 1573897.9099999964,
#  'PANDA': 1533131.1700000018,
#  'DISNEY BABY': 1368160.0,
#  'NEW LIFE': 1366045.62,
#  'BABY KING': 1354160.0,
#  'PYRAMID': 1318821.5899999999,
#  'KING STAR BABY': 1218082.7199999988,
#  'BURJ': 1174406.5700000003,
#  'SULTAN BABY': 1109411.08,
#  'JASMINE': 887078.620000001,
#  'ZARA': 881020.0,
#  'AVENGERS': 799659.7000000002,
#  'ELEGANT': 727000.0,
#  'KINGSTAR': 690881.3999999999,
#  'SUPER SLEEP': 626018.6599999999,
#  'JULIET': 582300.2800000003,
#  'AVENGERS (7)': 408882.2999999998,
#  'STOCK': 328201.54000000004,
#  'EVEREST': 307398.11,
#  'SIGNATURE': 107210.25,
#  'ABIDAL': 70093.68000000005,
#  'KING POWER': 61600.0,
#  'SOLARON SO': 57800.0,
#  'ZENEX': 14303.200000000012,
#  'ISTANBUL': 3400.0,
#  'DOLPHIN': 880.0,
#  'SUPER KING': 420.0,
#  'DOLPHIN GOLD': 385.0,
#  'SOLARON QUEEN': 300.0,
#  'SOLARON KING': 240.0,
#  'Series([], )': 0.0,
#  'AROMA GOLD': 0.0,
#  'ROMANTIC': -600.0,
#  'VENUS': -2350.0,
#  'DIAMOND KING': -3000.0,
#  'SOLARON BABY': -5600.0,
#  'PRIME TOUCH': -17250.0,
#  'SOLARON': -30908.0,
#  'GULF': -48650.0,
#  'SUNSET': -129411.2899999991,
#  'JASMINE (6) ': -546100.9800000004,
#  'KINGSTAR CLOUDY BABY': -2398662.0,
#  'JASMINE (2)': -5792920.0}

# %% [markdown]
# <h2> which brand highest sale:<h2>

# %%
saleBrand = {}

for ItemID, ItemID_df in transDetailsdf.groupby('ItemID'):
    saledf = ItemID_df[ItemID_df.TransType=='SALE']
    sale_sum = saledf.Amount.sum()
    saleBrand[Brand] = sale_sum

    ItemName, Brand = fetch_brand(ItemID)

    print('ItemID:',ItemID, 'sale:',sale_sum, 'brand:',Brand, ItemName )
# Out:
# ItemID: 0 sale: 0.0 brand: Series([], ) Series([], )
# ItemID: 10010001 sale: 27883400.0 brand: SULTAN 1PLY RASCHEL BLANKET
# ItemID: 10010002 sale: 27400960.0 brand: RIO 1PLY RASCHEL BLANKET
# ItemID: 10010003 sale: 21406600.0 brand: VICTORIYA 1PLY RASCHEL BLANKET
# ItemID: 10010004 sale: 48814150.0 brand: JASMINE 1PLY RASCHEL BLANKET
# ItemID: 10010005 sale: 22764740.0 brand: MASHREQ  1PLY RASCHEL BLANKET
# ItemID: 10020020 sale: 25200.0 brand: ROMANTIC 2PLY WEFT BLANKET
# ItemID: 10020021 sale: 10826850.0 brand: GOOD LIFE 2PLY RASCHEL BLANKET
# ItemID: 10020022 sale: 18605420.0 brand: SOLARON SOFT 2PLY CLOUDY BLANKET
# ItemID: 10020023 sale: 24264400.0 brand: MUGHAL 2PLY WEFT BLANKET
# ItemID: 10020024 sale: 55020.0 brand: SUPER KING 2PLY RASCHEL BLANKET
# ItemID: 10020025 sale: 32037520.0 brand: GOLDEN FLOWER 2PLY WEFT BLANKET
# ItemID: 10020026 sale: 18600.0 brand: SOLARON QUEEN 2PLY RASCHEL BLANKET
# ItemID: 10020027 sale: 1370000.0 brand: BABY KING 2PLY RASCHEL BABY
# ItemID: 10020028 sale: 9167500.0 brand: AROMA 2PLY CLOUDY BLANKET
# ItemID: 10020029 sale: 82500.0 brand: DIAMOND KING 2PLY WEFT BLANKET
# ItemID: 10020030 sale: 17395.0 brand: DOLPHIN GOLD 2PLY WEFT BLANKET
# ItemID: 10020031 sale: 33880.0 brand: DOLPHIN 2PLY WEFT BLANKET
# ItemID: 10020032 sale: 7113370.0 brand: JASMINE (6)  2PLY WEFT BLANKET
# ItemID: 10020033 sale: 17922400.0 brand: RASCHEL GOLD 2PLY RASCHEL BLANKET
# ItemID: 10020034 sale: 234400.0 brand: SOLARON BABY 2PLY CLOUDY
# ItemID: 10020035 sale: 6793220.0 brand: ZARA 2PLY WEFT BLANKET
# ItemID: 10020036 sale: 38389190.0 brand: PANDA 2PLY WEFT BLANKET
# ItemID: 10020037 sale: 13582330.0 brand: MICKEY & MOUSE BABY 2PLY CLOUDY BABY
# ItemID: 10020038 sale: 4948960.0 brand: DISNEY BABY 2PLY CLOUDY BABY
# ItemID: 10020039 sale: 1729280.0 brand: JASMINE (2) 2PLY WEFTBLANKET

# %%
print('brand sale highest to lowest: ')
dict(sorted(saleBrand.items(), reverse=True, key=lambda item: item[1]))
# Out:
# brand sale highest to lowest:
# {'GOLDEN FUN': 60906770.0,
#  'GOLDEN BABY': 59593900.0,
#  'VICTORIYA': 48814150.0,
#  'ELEGANT': 47648700.0,
#  'KING POWER GOLD': 38988240.0,
#  'ZARA': 38389190.0,
#  'BURJ': 37543750.0,
#  'VENUS': 36683710.0,
#  'TENDER TOUCH': 32983110.0,
#  'SUPER KING': 32037520.0,
#  'STOCK': 30452460.0,
#  'Series([], )': 27883400.0,
#  'ZENEX': 26263690.0,
#  'AVENGERS': 25289440.0,
#  'ABIDAL': 25257400.0,
#  'KING PRADO': 24716100.0,
#  'BREEZE': 24623120.0,
#  'SOLARON SOFT': 24264400.0,
#  'BLACK EAGLE': 24001800.0,
#  'KINGSTAR CLOUDY BABY': 23615580.0,
#  'EVEREST': 22427560.0,
#  'RIO': 21406600.0,
#  'KING POWER': 21195699.0,
#  'SOLARON SO': 21075340.0,
#  'RICHSHINE': 20503000.0,
#  'TAMILON': 20409540.0,
#  'QUEEN STAR': 19882780.0,
#  'GULF': 19546809.0,
#  'KINGSTAR': 18805600.0,
#  'GOOD LIFE': 18605420.0,
#  'JASMINE (6) ': 17922400.0,
#  'RAYMOND': 17644980.0,
#  'OLYMPIA GOLD': 16594050.0,
#  'PANDA': 13582330.0,
#  'TAMILON KING': 13134098.0,
#  'PYRAMID': 13041880.0,
#  'JASMINE': 12180730.0,
#  'SOLARON CLASSIC': 11200800.0,
#  'ROMANTIC': 10826850.0,
#  'NATURELIFE': 10533240.0,
#  'SULTAN BABY': 10013290.0,
#  'PRESIDENT': 9910320.0,
#  'SULTAN': 9665460.0,
#  'BABY KING': 9167500.0,
#  'ARSHIYA QUEEN': 8786590.0,
#  'AROMA GOLD': 8684700.0,
#  'NEW LIFE': 8381400.0,
#  'AVENGERS (7)': 7622900.0,
#  'DOLPHIN': 7113370.0,
#  'SOLARON BABY': 6793220.0,
#  'PRIME TOUCH': 6022360.0,
#  'KING STAR BABY': 5466870.0,
#  'TRUELOVE': 5380560.0,
#  'SUNSET': 5124600.0,
#  'MICKEY & MOUSE BABY': 4948960.0,
#  'SOLARON': 4539080.0,
#  'EMIRATES': 4103200.0,
#  'OASIS': 1991700.0,
#  'DISNEY BABY': 1729280.0,
#  'ROSELAND': 1708800.0,
#  'SIGNATURE': 1543200.0,
#  'SOLARON QUEEN': 1370000.0,
#  'ARABIAN KING': 1349400.0,
#  'MOOR GOLD': 662400.0,
#  'RASCHEL GOLD': 234400.0,
#  'CLOUDY PRINCE': 190750.0,
#  'ESKIMO GOLD': 185500.0,
#  'TAMILON GOLD': 170900.0,
#  'SOLARON KING': 128850.0,
#  'AROMA': 82500.0,
#  'ISTANBUL': 73850.0,
#  'MASHREQ ': 72400.0,
#  'SUPER SLEEP': 59040.0,
#  'MUGHAL': 55020.0,
#  'JULIET': 36800.0,
#  'DOLPHIN GOLD': 33880.0,
#  'GOLDEN HORSE': 25200.0,
#  'GOLDEN FLOWER': 18600.0,
#  'DIAMOND KING': 17395.0,
#  'JASMINE (2)': 0.0}

# %% [markdown]
# <h2> final: per day sell prediction in Qty(quantity):<h2>

# %%
transDetailsdf.head()
# Out:
#   TransType  TransDate  Year  TransNO  InvRefNo StoreFr StoreTo  PSID  \
# 0       BUY 2018-08-31  2018        1       NaN     NaN     S01   NaN
# 1       BUY 2018-08-31  2018        1       NaN     NaN     S01   NaN
# 2       BUY 2018-08-31  2018        1       NaN     NaN     S01   NaN
# 3       BUY 2018-08-31  2018        1       NaN     NaN     S01   NaN
# 4       BUY 2018-08-31  2018        1       NaN     NaN     S01   NaN
#
#            LCID  LCDate        Remarks  TransSl    ItemID    Unit   Qty  \
# 0  102050100001     1.0  OPENING STOCK        1  10010001  CARTON  2013
# 1  102050100001     1.0  OPENING STOCK       10  10010012  CARTON    64
# 2  102050100001     1.0  OPENING STOCK       11  10010014  CARTON    20
# 3  102050100001     1.0  OPENING STOCK       12  10010015  CARTON    16
# 4  102050100001     1.0  OPENING STOCK       13  10010032  CARTON    35
#
#      Rate     Amount    UserPc  UserId              InTime             IP  \
# 0  1700.0  3422100.0  mi3-wtr1   10101 2018-09-16 16:41:00   70.32.29.156
# 1  1940.0   124160.0  mi3-wtr1   10101 2018-10-31 19:43:00   70.32.29.156
# 2  1732.0    34640.0  mi3-wtr1   10101 2019-01-17 14:36:00  162.249.5.171
# 3  1936.0    30976.0  mi3-wtr1   10101 2019-01-17 17:24:00  162.249.5.171
# 4  2350.0    82250.0  mi3-wtr1   10101 2019-09-05 15:24:00  162.249.5.171
#
#           UpdatePC  UpdateUserID          UpdateTime       UpdateIP
# 0  WIN-COP36UURNHE       10101.0 2020-05-20 02:40:00  103.3.164.161
# 1         mi3-wtr1       10101.0 2019-10-01 17:10:00  162.249.5.171
# 2              NaN           NaN                 NaT            NaN
# 3              NaN           NaN                 NaT            NaN
# 4              NaN           NaN                 NaT            NaN

# %%
qtyList = []
for type, type_df in transDetailsdf.groupby('TransType'):
    if(type=='SALE'):
        for TransDate, TransDate_df in type_df.groupby('TransDate'):
            qtyList.append(TransDate_df['Qty'].sum())

# %%
import matplotlib.pyplot as plt

def histogram(dataList):
    plt.hist(dataList)
    plt.xlabel('data')
    plt.ylabel('Frequency')
    plt.show() 

def data_cleaning(dataArr): #input is np array to calculate std(), mean()
    upper_limit = dataArr.mean() + dataArr.std() #upper limit from std deviation
    lower_limit = dataArr.mean() - dataArr.std() #lower limit " " " "
    data_list = dataArr.tolist()

    clean_data = []
    for data in data_list:
        if(data<=upper_limit and data>=lower_limit):
            clean_data.append(data)

    return clean_data

# %%
def list_to_dataset(data_list):    
    histogram(data_list)
    dataArr = np.array(data_list)
    print('data length: ', len(data_list))
    qtyList = data_cleaning(dataArr)
    print('cleaned data length: ', len(data_cleaning(dataArr)))

    #convert data to dataframe
    dayCounter = 1
    data = []
    for item in data_list:
        data.append([dayCounter, item])
        dayCounter += 1

    df4 = pd.DataFrame(data, columns = ['Day', 'data'])
    print('dataframe: \n', df4)
    print(df4.head(630))

    #train test split
    x = df4.drop(['data'],axis='columns')
    y = df4.data

    from sklearn.model_selection import train_test_split
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)#, random_state=1)
    return x_train, x_test, y_train, y_test

# %%
qty_x_train, qty_x_test, qty_y_train, qty_y_test = list_to_dataset(qtyList)
# Out:
# data length:  702
# cleaned data length:  628
# dataframe:
#       Day  data
# 0      1   130
# 1      2  5242
# 2      3  4519
# 3      4   950
# 4      5   410
# ..   ...   ...
# 697  698  4638
# 698  699  3103
# 699  700  2400
# 700  701  4570
# 701  702  2166
#
# [702 rows x 2 columns]
#      Day  data
# 0      1   130
# 1      2  5242
# 2      3  4519
# 3      4   950
# 4      5   410
# ..   ...   ...
# 625  626    17
# 626  627   362
# 627  628  4170
# 628  629   638
# 629  630  1499
#
# [630 rows x 2 columns]

# %%
from sklearn.linear_model import LinearRegression
lr_clf = LinearRegression()
lr_clf.fit(qty_x_train,qty_y_train)
print('LinearRegression score:', lr_clf.score(qty_x_test, qty_y_test))

from sklearn.tree import DecisionTreeRegressor
# Fit regression model
regr = DecisionTreeRegressor(max_depth=2)
regr.fit(qty_x_train,qty_y_train)
print('DecisionTreeRegressor score:', regr.score(qty_x_test, qty_y_test))

from sklearn.svm import SVR
# Fit regression model
svr = SVR().fit(qty_x_train,qty_y_train)
print('SVR score:', svr.score(qty_x_test, qty_y_test))

from sklearn import linear_model
# Fit regression model
lassoReg = linear_model.Lasso(alpha=0.1)
lassoReg.fit(qty_x_train,qty_y_train)
print('lassoReg score:', lassoReg.score(qty_x_test, qty_y_test))
# Out:
# LinearRegression score: -0.0011299077694075788
# DecisionTreeRegressor score: 0.07717788151007099
# SVR score: -0.1132218583639708
# lassoReg score: -0.0011299791197292297

# %%
from sklearn.ensemble import RandomForestRegressor
rfr = RandomForestRegressor(max_depth=3)
rfr.fit(qty_x_train,qty_y_train)
print('RandomForestRegressor score:', rfr.score(qty_x_test, qty_y_test))
print('RandomForestRegressor is the best performing model')
print('RandomForestRegressor per day sell prediction in quantity(Qty):', rfr.predict([[629]]))
# Out:
# RandomForestRegressor score: 0.08518877137639758
# RandomForestRegressor is the best performing model
# RandomForestRegressor per day sell prediction in quantity(Qty): [1672.46915916]

# %% [markdown]
# <h2>per day sell prediction in Amount(money):<h2>

# %%
amountList = []
for type, type_df in transDetailsdf.groupby('TransType'):
    if(type=='SALE'):
        for TransDate, TransDate_df in type_df.groupby('TransDate'):
            amountList.append(TransDate_df['Amount'].sum()) #, TransDate_df['TransType'])

# %%
amount_x_train, amount_x_test, amount_y_train, amount_y_test = list_to_dataset(amountList)
# Out:
# data length:  702
# cleaned data length:  621
# dataframe:
#       Day        data
# 0      1    200600.0
# 1      2   5260190.0
# 2      3   5385950.0
# 3      4   1070000.0
# 4      5    795990.0
# ..   ...         ...
# 697  698  11459230.0
# 698  699   6157330.0
# 699  700   5388710.0
# 700  701  10185260.0
# 701  702   4723870.0
#
# [702 rows x 2 columns]
#      Day       data
# 0      1   200600.0
# 1      2  5260190.0
# 2      3  5385950.0
# 3      4  1070000.0
# 4      5   795990.0
# ..   ...        ...
# 625  626    35050.0
# 626  627   506880.0
# 627  628  9349010.0
# 628  629  1084810.0
# 629  630  3196000.0
#
# [630 rows x 2 columns]

# %%
from sklearn.linear_model import LinearRegression
lr_clf = LinearRegression()
lr_clf.fit(amount_x_train,amount_y_train)
print('LinearRegression score:', lr_clf.score(amount_x_test, amount_y_test))

from sklearn.tree import DecisionTreeRegressor
# Fit regression model
regr = DecisionTreeRegressor(max_depth=2)
regr.fit(amount_x_train,amount_y_train)
print('DecisionTreeRegressor score:', regr.score(amount_x_test, amount_y_test))

from sklearn.svm import SVR
# Fit regression model
svr = SVR().fit(amount_x_train,amount_y_train)
print('SVR score:', svr.score(amount_x_test, amount_y_test))

from sklearn import linear_model
# Fit regression model
lassoReg = linear_model.Lasso(alpha=0.1)
lassoReg.fit(amount_x_train,amount_y_train)
print('lassoReg score:', lassoReg.score(amount_x_test, amount_y_test))
# Out:
# LinearRegression score: -0.009988738658003093
# DecisionTreeRegressor score: 0.031199749402222032
# SVR score: -0.14334156173037127
# lassoReg score: -0.009988738606244052

# %%
from sklearn.ensemble import RandomForestRegressor
rfr = RandomForestRegressor(max_depth=3)
rfr.fit(amount_x_train,amount_y_train)
print('RandomForestRegressor score:', rfr.score(amount_x_test, amount_y_test))
print('RandomForestRegressor is the best performing model')
print('RandomForestRegressor per day sell prediction in moneyAmount:', rfr.predict([[629]])) #
# Out:
# RandomForestRegressor score: 0.10393201165406574
# RandomForestRegressor is the best performing model
# RandomForestRegressor per day sell prediction in moneyAmount: [3094575.98228077]

# %% [markdown]
# <h2>the end.<h2>
