# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_excel("Book1.xlsx")

# %%
data
# Out:
#       TransType  TransDate  Year  TransNO  InvRefNo StoreFr StoreTo  \
# 0           BUY 2018-08-31  2018        1       NaN     NaN     S01
# 1           BUY 2018-08-31  2018        1       NaN     NaN     S01
# 2           BUY 2018-08-31  2018        1       NaN     NaN     S01
# 3           BUY 2018-08-31  2018        1       NaN     NaN     S01
# 4           BUY 2018-08-31  2018        1       NaN     NaN     S01
# ...         ...        ...   ...      ...       ...     ...     ...
# 17566      SALE 2021-11-08  2021     1247    7272.0     S06     NaN
# 17567      SALE 2021-11-08  2021     1247    7272.0     S06     NaN
# 17568      SALE 2021-11-08  2021     1247    7272.0     S06     NaN
# 17569      SALE 2021-11-08  2021     1248    7273.0     S06     NaN
# 17570      SALE 2021-11-08  2021     1248    7273.0     S06     NaN
#
#                PSID          LCID  LCDate  ...           UserPc  UserId  \
# 0               NaN  102050100001     1.0  ...         mi3-wtr1   10101
# ...

# %%
data=data.drop(['UpdatePC','UpdateUserID','UpdateTime','UpdateIP','UserPc','InTime'],axis='columns')
data
# Out:
#       TransType  TransDate  Year  TransNO  InvRefNo StoreFr StoreTo  \
# 0           BUY 2018-08-31  2018        1       NaN     NaN     S01
# 1           BUY 2018-08-31  2018        1       NaN     NaN     S01
# 2           BUY 2018-08-31  2018        1       NaN     NaN     S01
# 3           BUY 2018-08-31  2018        1       NaN     NaN     S01
# 4           BUY 2018-08-31  2018        1       NaN     NaN     S01
# ...         ...        ...   ...      ...       ...     ...     ...
# 17566      SALE 2021-11-08  2021     1247    7272.0     S06     NaN
# 17567      SALE 2021-11-08  2021     1247    7272.0     S06     NaN
# 17568      SALE 2021-11-08  2021     1247    7272.0     S06     NaN
# 17569      SALE 2021-11-08  2021     1248    7273.0     S06     NaN
# 17570      SALE 2021-11-08  2021     1248    7273.0     S06     NaN
#
#                PSID          LCID  LCDate  ... TransSl              ItemName  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17571 entries, 0 to 17570
# Data columns (total 21 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TransType  17571 non-null  object
#  1   TransDate  17571 non-null  datetime64[ns]
#  2   Year       17571 non-null  int64
#  3   TransNO    17571 non-null  int64
#  4   InvRefNo   17069 non-null  float64
#  5   StoreFr    17069 non-null  object
#  6   StoreTo    502 non-null    object
#  7   PSID       17069 non-null  float64
#  8   LCID       17571 non-null  int64
#  9   LCDate     502 non-null    float64
#  10  Remarks    188 non-null    object
#  11  TransSl    17571 non-null  int64
#  12  ItemName   17571 non-null  object
#  13  Unit       17571 non-null  object
#  14  Qty        17571 non-null  int64
#  15  Rate       17571 non-null  float64
#  16  Amount     17571 non-null  float64
#  17  UserId     17571 non-null  int64
#  18  IP         17571 non-null  object
# ...

# %%
data
# Out:
#       TransType  TransDate  Year  TransNO  InvRefNo StoreFr StoreTo  \
# 0           BUY 2018-08-31  2018        1       NaN     NaN     S01
# 1           BUY 2018-08-31  2018        1       NaN     NaN     S01
# 2           BUY 2018-08-31  2018        1       NaN     NaN     S01
# 3           BUY 2018-08-31  2018        1       NaN     NaN     S01
# 4           BUY 2018-08-31  2018        1       NaN     NaN     S01
# ...         ...        ...   ...      ...       ...     ...     ...
# 17566      SALE 2021-11-08  2021     1247    7272.0     S06     NaN
# 17567      SALE 2021-11-08  2021     1247    7272.0     S06     NaN
# 17568      SALE 2021-11-08  2021     1247    7272.0     S06     NaN
# 17569      SALE 2021-11-08  2021     1248    7273.0     S06     NaN
# 17570      SALE 2021-11-08  2021     1248    7273.0     S06     NaN
#
#                PSID          LCID  LCDate  ... TransSl              ItemName  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17571 entries, 0 to 17570
# Data columns (total 21 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TransType  17571 non-null  object
#  1   TransDate  17571 non-null  datetime64[ns]
#  2   Year       17571 non-null  int64
#  3   TransNO    17571 non-null  int64
#  4   InvRefNo   17069 non-null  float64
#  5   StoreFr    17069 non-null  object
#  6   StoreTo    502 non-null    object
#  7   PSID       17069 non-null  float64
#  8   LCID       17571 non-null  int64
#  9   LCDate     502 non-null    float64
#  10  Remarks    188 non-null    object
#  11  TransSl    17571 non-null  int64
#  12  ItemName   17571 non-null  object
#  13  Unit       17571 non-null  object
#  14  Qty        17571 non-null  int64
#  15  Rate       17571 non-null  float64
#  16  Amount     17571 non-null  float64
#  17  UserId     17571 non-null  int64
#  18  IP         17571 non-null  object
# ...

# %%
data
# Out:
#       TransType  TransDate  Year  TransNO  InvRefNo StoreFr StoreTo  \
# 0           BUY 2018-08-31  2018        1       NaN     NaN     S01
# 1           BUY 2018-08-31  2018        1       NaN     NaN     S01
# 2           BUY 2018-08-31  2018        1       NaN     NaN     S01
# 3           BUY 2018-08-31  2018        1       NaN     NaN     S01
# 4           BUY 2018-08-31  2018        1       NaN     NaN     S01
# ...         ...        ...   ...      ...       ...     ...     ...
# 17566      SALE 2021-11-08  2021     1247    7272.0     S06     NaN
# 17567      SALE 2021-11-08  2021     1247    7272.0     S06     NaN
# 17568      SALE 2021-11-08  2021     1247    7272.0     S06     NaN
# 17569      SALE 2021-11-08  2021     1248    7273.0     S06     NaN
# 17570      SALE 2021-11-08  2021     1248    7273.0     S06     NaN
#
#                PSID          LCID  LCDate  ... TransSl              ItemName  \
# ...

# %%
data=data.drop(['UserId','Unit','IP','PSID','LCID','LCDate','TransSl'],axis='columns')
data
# Out:
#       TransType  TransDate  Year  TransNO  InvRefNo StoreFr StoreTo  \
# 0           BUY 2018-08-31  2018        1       NaN     NaN     S01
# 1           BUY 2018-08-31  2018        1       NaN     NaN     S01
# 2           BUY 2018-08-31  2018        1       NaN     NaN     S01
# 3           BUY 2018-08-31  2018        1       NaN     NaN     S01
# 4           BUY 2018-08-31  2018        1       NaN     NaN     S01
# ...         ...        ...   ...      ...       ...     ...     ...
# 17566      SALE 2021-11-08  2021     1247    7272.0     S06     NaN
# 17567      SALE 2021-11-08  2021     1247    7272.0     S06     NaN
# 17568      SALE 2021-11-08  2021     1247    7272.0     S06     NaN
# 17569      SALE 2021-11-08  2021     1248    7273.0     S06     NaN
# 17570      SALE 2021-11-08  2021     1248    7273.0     S06     NaN
#
#              Remarks              ItemName   Qty    Rate     Amount  \
# 0      OPENING STOCK  1PLY RASCHEL BLANKET  2013  1700.0  3422100.0
# ...

# %%
buy=pd.read_excel("buy.xlsx")
buy
# Out:
#     TransType  TransDate  Year  TransNO  InvRefNo  StoreFr StoreTo  PSID  \
# 0         BUY 2018-08-31  2018        1       NaN      NaN     S01   NaN
# 1         BUY 2018-08-31  2018        1       NaN      NaN     S01   NaN
# 2         BUY 2018-08-31  2018        1       NaN      NaN     S01   NaN
# 3         BUY 2018-08-31  2018        1       NaN      NaN     S01   NaN
# 4         BUY 2018-08-31  2018        1       NaN      NaN     S01   NaN
# ..        ...        ...   ...      ...       ...      ...     ...   ...
# 497       BUY 2021-11-01  2021       30       NaN      NaN     S06   NaN
# 498       BUY 2021-11-01  2021       30       NaN      NaN     S06   NaN
# 499       BUY 2021-11-02  2021       31       NaN      NaN     S06   NaN
# 500       BUY 2021-11-02  2021       32       NaN      NaN     S06   NaN
# 501       BUY 2021-11-02  2021       32       NaN      NaN     S06   NaN
#
#              LCID  LCDate  ...           UserPc  UserId              InTime  \
# ...

# %%
buy=buy.drop(['UpdatePC','UpdateUserID','UpdateTime','UpdateIP','UserPc','InTime','UserId','Unit','IP','PSID','LCID','LCDate','TransSl','InvRefNo','StoreFr','Remarks'],axis='columns')
buy
# Out:
#     TransType  TransDate  Year  TransNO StoreTo              ItemName    Qty  \
# 0         BUY 2018-08-31  2018        1     S01  1PLY RASCHEL BLANKET   2013
# 1         BUY 2018-08-31  2018        1     S01  1PLY RASCHEL BLANKET     64
# 2         BUY 2018-08-31  2018        1     S01  1PLY RASCHEL BLANKET     20
# 3         BUY 2018-08-31  2018        1     S01  1PLY RASCHEL BLANKET     16
# 4         BUY 2018-08-31  2018        1     S01  1PLY RASCHEL BLANKET     35
# ..        ...        ...   ...      ...     ...                   ...    ...
# 497       BUY 2021-11-01  2021       30     S06  1PLY RASCHEL BLANKET   1440
# 498       BUY 2021-11-01  2021       30     S06  1PLY RASCHEL BLANKET  13846
# 499       BUY 2021-11-02  2021       31     S06     2PLY WEFT BLANKET   5038
# 500       BUY 2021-11-02  2021       32     S06  2PLY RASCHEL BLANKET   2694
# 501       BUY 2021-11-02  2021       32     S06  2PLY RASCHEL BLANKET     88
#
# ...

# %%
sale=pd.read_excel("SALE.xlsx")
sale
# Out:
#       TransType  TransDate  Year  TransNO  InvRefNo StoreFr  StoreTo  \
# 0          SALE 2018-09-03  2018        1      1624     S01      NaN
# 1          SALE 2018-09-03  2018        1      1624     S01      NaN
# 2          SALE 2018-09-03  2018        2      1625     S01      NaN
# 3          SALE 2018-09-04  2018        3      1626     S01      NaN
# 4          SALE 2018-09-04  2018        3      1626     S01      NaN
# ...         ...        ...   ...      ...       ...     ...      ...
# 17064      SALE 2021-11-08  2021     1247      7272     S06      NaN
# 17065      SALE 2021-11-08  2021     1247      7272     S06      NaN
# 17066      SALE 2021-11-08  2021     1247      7272     S06      NaN
# 17067      SALE 2021-11-08  2021     1248      7273     S06      NaN
# 17068      SALE 2021-11-08  2021     1248      7273     S06      NaN
#
#                PSID          LCID  LCDate  ...           UserPc  UserId  \
# ...

# %%
sale=sale.drop(['UpdatePC','UpdateUserID','UpdateTime','UpdateIP','UserPc','InTime','UserId','Unit','IP','PSID','LCID','LCDate','TransSl','InvRefNo','StoreFr','Remarks','StoreTo'],axis='columns')
sale
# Out:
#       TransType  TransDate  Year  TransNO              ItemName  Qty  Rate  \
# 0          SALE 2018-09-03  2018        1  1PLY RASCHEL BLANKET   50  1500
# 1          SALE 2018-09-03  2018        1  1PLY RASCHEL BLANKET   60  1500
# 2          SALE 2018-09-03  2018        2  1PLY RASCHEL BLANKET   20  1780
# 3          SALE 2018-09-04  2018        3  1PLY RASCHEL BLANKET   60  3250
# 4          SALE 2018-09-04  2018        3  1PLY RASCHEL BLANKET  200  1780
# ...         ...        ...   ...      ...                   ...  ...   ...
# 17064      SALE 2021-11-08  2021     1247     2PLY WEFT BLANKET   24  2270
# 17065      SALE 2021-11-08  2021     1247     2PLY WEFT BLANKET   28  2550
# 17066      SALE 2021-11-08  2021     1247  2PLY RASCHEL BLANKET   18  3200
# 17067      SALE 2021-11-08  2021     1248     2PLY WEFT BLANKET   21  2550
# 17068      SALE 2021-11-08  2021     1248     2PLY WEFT BLANKET   24  2250
#
#        Amount         Brand    ItemID
# ...

# %%
data['Amount'].max()
# Out:
# 13336170.48

# %%
data.loc[data['Amount'] ==data['Amount'].max()]
# Out:
#     TransType  TransDate  Year  TransNO  InvRefNo StoreFr StoreTo Remarks  \
# 369       BUY 2020-02-16  2020        5       NaN     NaN     S06     NaN
#
#                  ItemName   Qty     Rate       Amount           ItemID  \
# 369  1PLY RASCHEL BLANKET  7992  1668.69  13336170.48  KING POWER GOLD
#
#      ItemID.1
# 369  10010048
